# %%
import os

from langchain_classic.chains import RetrievalQA
from langchain_community.vectorstores import Chroma
from langchain_community.chat_models import ChatTongyi
from langchain_community.document_loaders import TextLoader
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_text_splitters import CharacterTextSplitter

os.environ["DASHSCOPE_API_KEY"] = "sk-xxxxx"  # 替换为你的真实 API Key

# 加载文档
loader = TextLoader("新闻介绍.txt", encoding="utf-8")
documents = loader.load()

# 分割文档
text_splitter = CharacterTextSplitter(chunk_size=1000, chunk_overlap=100)
texts = text_splitter.split_documents(documents)

# 使用 huggingface 的 embedding
embeddings = HuggingFaceEmbeddings(
    model_name="sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2"
)

# 创建向量数据库
db = Chroma.from_documents(texts, embeddings)

# 使用通义千问 LLM
llm = ChatTongyi(model_name="qwen3.6-plus")

# 构建问答链
qa = RetrievalQA.from_chain_type(
    llm=llm,
    chain_type="stuff",
    retriever=db.as_retriever()
)

query = "中国青年网民对 AI 社交有什么看法？"
result = qa.run(query)
print(result)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 21
#      18 texts = text_splitter.split_documents(documents)
#      20 # 使用 huggingface 的 embedding
# ---> 21 embeddings = HuggingFaceEmbeddings(
#      22     model_name="sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2"
#      23 )
#      25 # 创建向量数据库
#      26 db = Chroma.from_documents(texts, embeddings)
#
# File D:\Program Files (x86)\JetBrains\python_project\python_study_project\.venv\Lib\site-packages\langchain_huggingface\embeddings\huggingface.py:68, in HuggingFaceEmbeddings.__init__(self, **kwargs)
#      66 super().__init__(**kwargs)
#      67 try:
# ---> 68     import sentence_transformers  # type: ignore[import]
#      69 except ImportError as exc:
#      70     msg = (
#      71         "Could not import sentence_transformers python package. "
#      72         "Please install it with `pip install sentence-transformers`."
#      73     )
#
# File D:\Program Files (x86)\JetBrains\python_project\python_study_project\.venv\Lib\site-packages\sentence_transformers\__init__.py:10
#       7 import os
#       8 import warnings
# ---> 10 from sentence_transformers.backend import (
#      11     export_dynamic_quantized_onnx_model,
#      12     export_optimized_onnx_model,
#      13     export_static_quantized_openvino_model,
#      14 )
#      15 from sentence_transformers.base.sampler import DefaultBatchSampler, MultiDatasetDefaultBatchSampler
#      16 from sentence_transformers.cross_encoder import (
#      17     CrossEncoder,
#      18     CrossEncoderModelCardData,
#      19     CrossEncoderTrainer,
#      20     CrossEncoderTrainingArguments,
#      21 )
#
# File D:\Program Files (x86)\JetBrains\python_project\python_study_project\.venv\Lib\site-packages\sentence_transformers\backend\__init__.py:3
#       1 from __future__ import annotations
# ----> 3 from .load import load_onnx_model, load_openvino_model
#       4 from .optimize import export_optimized_onnx_model
#       5 from .quantize import export_dynamic_quantized_onnx_model, export_static_quantized_openvino_model
#
# File D:\Program Files (x86)\JetBrains\python_project\python_study_project\.venv\Lib\site-packages\sentence_transformers\backend\load.py:7
#       4 import logging
#       5 from pathlib import Path
# ----> 7 from transformers.configuration_utils import PretrainedConfig
#       9 from sentence_transformers.backend.utils import _save_pretrained_wrapper, backend_should_export, backend_warn_to_save
#      11 logger = logging.getLogger(__name__)
#
# File D:\Program Files (x86)\JetBrains\python_project\python_study_project\.venv\Lib\site-packages\transformers\configuration_utils.py:32
#      30 from . import __version__
#      31 from .dynamic_module_utils import custom_object_save
# ---> 32 from .generation.configuration_utils import GenerationConfig
#      33 from .modeling_gguf_pytorch_utils import load_gguf_checkpoint
#      34 from .modeling_rope_utils import RotaryEmbeddingConfigMixin
#
# File D:\Program Files (x86)\JetBrains\python_project\python_study_project\.venv\Lib\site-packages\transformers\generation\configuration_utils.py:62
#      58 ALL_CACHE_IMPLEMENTATIONS = ALL_STATIC_CACHE_IMPLEMENTATIONS + DYNAMIC_CACHE_IMPLEMENTATIONS
#      61 if is_torch_available():
# ---> 62     from .logits_process import SynthIDTextWatermarkLogitsProcessor, WatermarkLogitsProcessor
#      65 class GenerationMode(ExplicitEnum):
#      66     """
#      67     Possible generation modes, downstream of the [`~generation.GenerationMixin.generate`] method.
#      68     """
#
# File D:\Program Files (x86)\JetBrains\python_project\python_study_project\.venv\Lib\site-packages\transformers\generation\logits_process.py:21
#      18 from typing import TYPE_CHECKING, Any, cast
#      20 import numpy as np
# ---> 21 import torch
#      23 from .._typing import WhisperGenerationConfigLike
#      24 from ..utils import add_start_docstrings
#
# File D:\Program Files (x86)\JetBrains\python_project\python_study_project\.venv\Lib\site-packages\torch\__init__.py:560
#     546         raise ImportError(textwrap.dedent('''
#     547             Failed to load PyTorch C extensions:
#     548                 It appears that PyTorch has loaded the `torch/_C` folder
#    (...)    556                 or by running Python from a different directory.
#     557             ''').strip()) from None
#     558     raise  # If __file__ is not None the cause is unknown, so just re-raise.
# --> 560 for name in dir(_C):
#     561     if name[0] != '_' and not name.endswith('Base'):
#     562         __all__.append(name)
#
# NameError: name '_C' is not defined
